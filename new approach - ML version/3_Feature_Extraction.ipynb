# %%
import os

import skimage as ski
from pprint import pprint
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

import polars as pl

# %%
class LineCombination:
    def __init__(self, start, finish):
        self.start = start
        self.finish = finish
        self.points = []
        self.score = 0
        self.percent = 0.0

    def __str__(self):
        return f"{self.start}-{self.finish}\t{len(self.points)}/{self.score}\tpercent={round(self.percent, 2)} %)"

    def __repr__(self):
        return f"{self.start}-{self.finish}\t{len(self.points)}/{self.score}\tpercent={round(self.percent, 2)} %)"

# %%
def draw_huge_line(comb: LineCombination, shape, start, finish):
    if start[0] == finish[0]:
        for y in range(shape[1]):
            p = (start[0], y)
            comb.points.append(p)
    else:
        slope = (float(finish[1]) - float(start[1])) / (float(finish[0]) - float(start[0]))
        intercept = float(start[1]) - slope * float(start[0])

        for i in range(shape[0]):
            y = slope * i + intercept
            p = (i, round(y))
            comb.points.append(p)

# %%
def feature_generator(path: str) -> tuple[int, float, int, float, int, int, int]:
    img = cv.imread(path)

    blurred = cv.GaussianBlur(img, (9,9), 0)
    gray = cv.cvtColor(blurred,cv.COLOR_BGRA2GRAY)
    
    # Shape and contour detection
    ret, img_tresh = cv.threshold(gray,20,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
    a1, a2 = cv.findContours(img_tresh, cv.RETR_EXTERNAL,cv.CHAIN_APPROX_SIMPLE)
    tetetet = cv.approxPolyDP(a1[0], 0.01*cv.arcLength(a1[0],True),True)

    # Corner detection
    corner_grey = np.float32(gray)
    corners = cv.goodFeaturesToTrack(corner_grey, 25, 0.01, 10)
    corners = np.intp(corners)
    

    total_corners = cv.goodFeaturesToTrack(corner_grey, 0, 0.01, 10)

    # Circle detection
    circles = cv.HoughCircles(gray, cv.HOUGH_GRADIENT_ALT, 1.5, 5, param1=300, param2=0.7, minRadius=10, maxRadius=0)

    # Line detection
    lines: list[LineCombination] = []
    edges = cv.Canny(gray, 50, 50)
    thick = cv.dilate(edges, None, iterations=2)

    # get all possible line combinations
    for i in range(len(corners)):
        for j in range(i + 1, len(corners)):
            # get start and finish point
            start = corners[i][0]
            finish = corners[j][0]

            lines.append(LineCombination(start, finish))

    for comb in lines:
        draw_huge_line(comb, gray.shape, comb.start, comb.finish)

    for comb in lines:
        for point in reversed(comb.points):
            if point[0] >= thick.shape[0] or point[1] >= thick.shape[1] \
                    or point[0] < 0 or point[1] < 0:
                comb.points.remove(point)

    # clear duplicate points (if any) (optional)
    for comb in lines:
        comb.points = list(set(comb.points))

    # calculate score for each line combination and success percentage
    for line in lines:
        for point in line.points:
            if thick[point[0]][point[1]] == 255:
                line.score += 1

        # calculate percentage
        line.percent = round(line.score / 400 * 100, 2)


    sorted_by_percentage = sorted(lines, key=lambda x: x.percent, reverse=True)
    # get all lines with percentage >= 25% a.k.a. num_lines
    quarter_successfull_lines = filter(lambda x: x.percent >= 25.0, sorted_by_percentage)
    
    return tetetet.shape[0], cv.contourArea(tetetet), sorted_by_percentage[0].score, sorted_by_percentage[0].percent, len(circles[0]) if circles is not None else 0, len(list(quarter_successfull_lines)), len(total_corners)

# %%
paths = os.listdir('dataset')
parts = {}

for p in paths:
    if p.endswith('.png'):
        code = p.split(' ', 1)[0]
        if parts.get(code) is None:
            parts[code] = [p]
        else:
            parts[code].append(p)
results = []
requested = ["3001", "4286", "2780", "6632", "99301", "43093", "54200"]

done = 0
total = sum([len(parts[v]) for v in parts.keys() if v in requested])
total
# Out:
# 5600

# %%
for code, path in parts.items():
    if code in requested:
        for p in path:
            print(f"Processing {p}, {done}/{total}, {round(done/total*100, 2)}%")
            results.append([code, *feature_generator('dataset/' + p)])
            done += 1
# Out:
# Processing 2780 Peg with friction 000L.png, 0/5600, 0.0%
# Processing 2780 Peg with friction 000R.png, 1/5600, 0.02%
# Processing 2780 Peg with friction 001L.png, 2/5600, 0.04%
# Processing 2780 Peg with friction 001R.png, 3/5600, 0.05%
# Processing 2780 Peg with friction 002L.png, 4/5600, 0.07%
# Processing 2780 Peg with friction 002R.png, 5/5600, 0.09%
# Processing 2780 Peg with friction 003L.png, 6/5600, 0.11%
# Processing 2780 Peg with friction 003R.png, 7/5600, 0.12%
# Processing 2780 Peg with friction 004L.png, 8/5600, 0.14%
# Processing 2780 Peg with friction 004R.png, 9/5600, 0.16%
# Processing 2780 Peg with friction 005L.png, 10/5600, 0.18%
# Processing 2780 Peg with friction 005R.png, 11/5600, 0.2%
# Processing 2780 Peg with friction 006L.png, 12/5600, 0.21%
# Processing 2780 Peg with friction 006R.png, 13/5600, 0.23%
# Processing 2780 Peg with friction 007L.png, 14/5600, 0.25%
# Processing 2780 Peg with friction 007R.png, 15/5600, 0.27%
# Processing 2780 Peg with friction 008L.png, 16/5600, 0.29%
# Processing 2780 Peg with friction 008R.png, 17/5600, 0.3%
# Processing 2780 Peg with friction 009L.png, 18/5600, 0.32%
# Processing 2780 Peg with friction 009R.png, 19/5600, 0.34%
# Processing 2780 Peg with friction 010L.png, 20/5600, 0.36%
# Processing 2780 Peg with friction 010R.png, 21/5600, 0.38%
# Processing 2780 Peg with friction 011L.png, 22/5600, 0.39%
# Processing 2780 Peg with friction 011R.png, 23/5600, 0.41%
# Processing 2780 Peg with friction 012L.png, 24/5600, 0.43%
# Processing 2780 Peg with friction 012R.png, 25/5600, 0.45%
# Processing 2780 Peg with friction 013L.png, 26/5600, 0.46%
# Processing 2780 Peg with friction 013R.png, 27/5600, 0.48%
# Processing 2780 Peg with friction 014L.png, 28/5600, 0.5%
# Processing 2780 Peg with friction 014R.png, 29/5600, 0.52%
# Processing 2780 Peg with friction 015L.png, 30/5600, 0.54%
# Processing 2780 Peg with friction 015R.png, 31/5600, 0.55%
# Processing 2780 Peg with friction 016L.png, 32/5600, 0.57%
# Processing 2780 Peg with friction 016R.png, 33/5600, 0.59%
# Processing 2780 Peg with friction 017L.png, 34/5600, 0.61%
# Processing 2780 Peg with friction 017R.png, 35/5600, 0.62%
# Processing 2780 Peg with friction 018L.png, 36/5600, 0.64%
# Processing 2780 Peg with friction 018R.png, 37/5600, 0.66%
# Processing 2780 Peg with friction 019L.png, 38/5600, 0.68%
# Processing 2780 Peg with friction 019R.png, 39/5600, 0.7%
# Processing 2780 Peg with friction 020L.png, 40/5600, 0.71%
# Processing 2780 Peg with friction 020R.png, 41/5600, 0.73%
# Processing 2780 Peg with friction 021L.png, 42/5600, 0.75%
# Processing 2780 Peg with friction 021R.png, 43/5600, 0.77%
# Processing 2780 Peg with friction 022L.png, 44/5600, 0.79%
# Processing 2780 Peg with friction 022R.png, 45/5600, 0.8%
# Processing 2780 Peg with friction 023L.png, 46/5600, 0.82%
# Processing 2780 Peg with friction 023R.png, 47/5600, 0.84%
# Processing 2780 Peg with friction 024L.png, 48/5600, 0.86%
# Processing 2780 Peg with friction 024R.png, 49/5600, 0.88%
# Processing 2780 Peg with friction 025L.png, 50/5600, 0.89%
# Processing 2780 Peg with friction 025R.png, 51/5600, 0.91%
# Processing 2780 Peg with friction 026L.png, 52/5600, 0.93%
# Processing 2780 Peg with friction 026R.png, 53/5600, 0.95%
# Processing 2780 Peg with friction 027L.png, 54/5600, 0.96%
# Processing 2780 Peg with friction 027R.png, 55/5600, 0.98%
# Processing 2780 Peg with friction 028L.png, 56/5600, 1.0%
# Processing 2780 Peg with friction 028R.png, 57/5600, 1.02%
# Processing 2780 Peg with friction 029L.png, 58/5600, 1.04%
# Processing 2780 Peg with friction 029R.png, 59/5600, 1.05%
# Processing 2780 Peg with friction 030L.png, 60/5600, 1.07%
# Processing 2780 Peg with friction 030R.png, 61/5600, 1.09%
# Processing 2780 Peg with friction 031L.png, 62/5600, 1.11%
# Processing 2780 Peg with friction 031R.png, 63/5600, 1.12%
# Processing 2780 Peg with friction 032L.png, 64/5600, 1.14%
# Processing 2780 Peg with friction 032R.png, 65/5600, 1.16%
# Processing 2780 Peg with friction 033L.png, 66/5600, 1.18%
# Processing 2780 Peg with friction 033R.png, 67/5600, 1.2%
# Processing 2780 Peg with friction 034L.png, 68/5600, 1.21%
# Processing 2780 Peg with friction 034R.png, 69/5600, 1.23%
# Processing 2780 Peg with friction 035L.png, 70/5600, 1.25%
# Processing 2780 Peg with friction 035R.png, 71/5600, 1.27%
# Processing 2780 Peg with friction 036L.png, 72/5600, 1.29%
# Processing 2780 Peg with friction 036R.png, 73/5600, 1.3%
# Processing 2780 Peg with friction 037L.png, 74/5600, 1.32%
# Processing 2780 Peg with friction 037R.png, 75/5600, 1.34%
# Processing 2780 Peg with friction 038L.png, 76/5600, 1.36%
# Processing 2780 Peg with friction 038R.png, 77/5600, 1.38%
# Processing 2780 Peg with friction 039L.png, 78/5600, 1.39%
# Processing 2780 Peg with friction 039R.png, 79/5600, 1.41%
# Processing 2780 Peg with friction 040L.png, 80/5600, 1.43%
# Processing 2780 Peg with friction 040R.png, 81/5600, 1.45%
# Processing 2780 Peg with friction 041L.png, 82/5600, 1.46%
# Processing 2780 Peg with friction 041R.png, 83/5600, 1.48%
# Processing 2780 Peg with friction 042L.png, 84/5600, 1.5%
# Processing 2780 Peg with friction 042R.png, 85/5600, 1.52%
# Processing 2780 Peg with friction 043L.png, 86/5600, 1.54%
# Processing 2780 Peg with friction 043R.png, 87/5600, 1.55%
# Processing 2780 Peg with friction 044L.png, 88/5600, 1.57%
# Processing 2780 Peg with friction 044R.png, 89/5600, 1.59%
# Processing 2780 Peg with friction 045L.png, 90/5600, 1.61%
# Processing 2780 Peg with friction 045R.png, 91/5600, 1.62%
# Processing 2780 Peg with friction 046L.png, 92/5600, 1.64%
# Processing 2780 Peg with friction 046R.png, 93/5600, 1.66%
# Processing 2780 Peg with friction 047L.png, 94/5600, 1.68%
# Processing 2780 Peg with friction 047R.png, 95/5600, 1.7%
# Processing 2780 Peg with friction 048L.png, 96/5600, 1.71%
# Processing 2780 Peg with friction 048R.png, 97/5600, 1.73%
# Processing 2780 Peg with friction 049L.png, 98/5600, 1.75%
# Processing 2780 Peg with friction 049R.png, 99/5600, 1.77%
# Processing 2780 Peg with friction 050L.png, 100/5600, 1.79%
# Processing 2780 Peg with friction 050R.png, 101/5600, 1.8%
# Processing 2780 Peg with friction 051L.png, 102/5600, 1.82%
# Processing 2780 Peg with friction 051R.png, 103/5600, 1.84%
# Processing 2780 Peg with friction 052L.png, 104/5600, 1.86%
# Processing 2780 Peg with friction 052R.png, 105/5600, 1.88%
# Processing 2780 Peg with friction 053L.png, 106/5600, 1.89%
# Processing 2780 Peg with friction 053R.png, 107/5600, 1.91%
# Processing 2780 Peg with friction 054L.png, 108/5600, 1.93%
# Processing 2780 Peg with friction 054R.png, 109/5600, 1.95%
# Processing 2780 Peg with friction 055L.png, 110/5600, 1.96%
# Processing 2780 Peg with friction 055R.png, 111/5600, 1.98%
# Processing 2780 Peg with friction 056L.png, 112/5600, 2.0%
# Processing 2780 Peg with friction 056R.png, 113/5600, 2.02%
# Processing 2780 Peg with friction 057L.png, 114/5600, 2.04%
# Processing 2780 Peg with friction 057R.png, 115/5600, 2.05%
# Processing 2780 Peg with friction 058L.png, 116/5600, 2.07%
# Processing 2780 Peg with friction 058R.png, 117/5600, 2.09%
# Processing 2780 Peg with friction 059L.png, 118/5600, 2.11%
# Processing 2780 Peg with friction 059R.png, 119/5600, 2.12%
# Processing 2780 Peg with friction 060L.png, 120/5600, 2.14%
# Processing 2780 Peg with friction 060R.png, 121/5600, 2.16%
# Processing 2780 Peg with friction 061L.png, 122/5600, 2.18%
# Processing 2780 Peg with friction 061R.png, 123/5600, 2.2%
# Processing 2780 Peg with friction 062L.png, 124/5600, 2.21%
# Processing 2780 Peg with friction 062R.png, 125/5600, 2.23%
# Processing 2780 Peg with friction 063L.png, 126/5600, 2.25%
# Processing 2780 Peg with friction 063R.png, 127/5600, 2.27%
# Processing 2780 Peg with friction 064L.png, 128/5600, 2.29%
# Processing 2780 Peg with friction 064R.png, 129/5600, 2.3%
# Processing 2780 Peg with friction 065L.png, 130/5600, 2.32%
# Processing 2780 Peg with friction 065R.png, 131/5600, 2.34%
# Processing 2780 Peg with friction 066L.png, 132/5600, 2.36%
# Processing 2780 Peg with friction 066R.png, 133/5600, 2.38%
# Processing 2780 Peg with friction 067L.png, 134/5600, 2.39%
# Processing 2780 Peg with friction 067R.png, 135/5600, 2.41%
# Processing 2780 Peg with friction 068L.png, 136/5600, 2.43%
# Processing 2780 Peg with friction 068R.png, 137/5600, 2.45%
# Processing 2780 Peg with friction 069L.png, 138/5600, 2.46%
# Processing 2780 Peg with friction 069R.png, 139/5600, 2.48%
# Processing 2780 Peg with friction 070L.png, 140/5600, 2.5%
# Processing 2780 Peg with friction 070R.png, 141/5600, 2.52%
# Processing 2780 Peg with friction 071L.png, 142/5600, 2.54%
# Processing 2780 Peg with friction 071R.png, 143/5600, 2.55%
# Processing 2780 Peg with friction 072L.png, 144/5600, 2.57%
# Processing 2780 Peg with friction 072R.png, 145/5600, 2.59%
# Processing 2780 Peg with friction 073L.png, 146/5600, 2.61%
# Processing 2780 Peg with friction 073R.png, 147/5600, 2.62%
# Processing 2780 Peg with friction 074L.png, 148/5600, 2.64%
# Processing 2780 Peg with friction 074R.png, 149/5600, 2.66%
# Processing 2780 Peg with friction 075L.png, 150/5600, 2.68%
# Processing 2780 Peg with friction 075R.png, 151/5600, 2.7%
# Processing 2780 Peg with friction 076L.png, 152/5600, 2.71%
# Processing 2780 Peg with friction 076R.png, 153/5600, 2.73%
# Processing 2780 Peg with friction 077L.png, 154/5600, 2.75%
# Processing 2780 Peg with friction 077R.png, 155/5600, 2.77%
# Processing 2780 Peg with friction 078L.png, 156/5600, 2.79%
# Processing 2780 Peg with friction 078R.png, 157/5600, 2.8%
# Processing 2780 Peg with friction 079L.png, 158/5600, 2.82%
# Processing 2780 Peg with friction 079R.png, 159/5600, 2.84%
# Processing 2780 Peg with friction 080L.png, 160/5600, 2.86%
# Processing 2780 Peg with friction 080R.png, 161/5600, 2.88%
# Processing 2780 Peg with friction 081L.png, 162/5600, 2.89%
# Processing 2780 Peg with friction 081R.png, 163/5600, 2.91%
# Processing 2780 Peg with friction 082L.png, 164/5600, 2.93%
# Processing 2780 Peg with friction 082R.png, 165/5600, 2.95%
# Processing 2780 Peg with friction 083L.png, 166/5600, 2.96%
# Processing 2780 Peg with friction 083R.png, 167/5600, 2.98%
# Processing 2780 Peg with friction 084L.png, 168/5600, 3.0%
# Processing 2780 Peg with friction 084R.png, 169/5600, 3.02%
# Processing 2780 Peg with friction 085L.png, 170/5600, 3.04%
# Processing 2780 Peg with friction 085R.png, 171/5600, 3.05%
# Processing 2780 Peg with friction 086L.png, 172/5600, 3.07%
# Processing 2780 Peg with friction 086R.png, 173/5600, 3.09%
# Processing 2780 Peg with friction 087L.png, 174/5600, 3.11%
# Processing 2780 Peg with friction 087R.png, 175/5600, 3.12%
# Processing 2780 Peg with friction 088L.png, 176/5600, 3.14%
# Processing 2780 Peg with friction 088R.png, 177/5600, 3.16%
# Processing 2780 Peg with friction 089L.png, 178/5600, 3.18%
# Processing 2780 Peg with friction 089R.png, 179/5600, 3.2%
# Processing 2780 Peg with friction 090L.png, 180/5600, 3.21%
# Processing 2780 Peg with friction 090R.png, 181/5600, 3.23%
# Processing 2780 Peg with friction 091L.png, 182/5600, 3.25%
# Processing 2780 Peg with friction 091R.png, 183/5600, 3.27%
# Processing 2780 Peg with friction 092L.png, 184/5600, 3.29%
# Processing 2780 Peg with friction 092R.png, 185/5600, 3.3%
# Processing 2780 Peg with friction 093L.png, 186/5600, 3.32%
# Processing 2780 Peg with friction 093R.png, 187/5600, 3.34%
# Processing 2780 Peg with friction 094L.png, 188/5600, 3.36%
# Processing 2780 Peg with friction 094R.png, 189/5600, 3.38%
# Processing 2780 Peg with friction 095L.png, 190/5600, 3.39%
# Processing 2780 Peg with friction 095R.png, 191/5600, 3.41%
# Processing 2780 Peg with friction 096L.png, 192/5600, 3.43%
# Processing 2780 Peg with friction 096R.png, 193/5600, 3.45%
# Processing 2780 Peg with friction 097L.png, 194/5600, 3.46%
# Processing 2780 Peg with friction 097R.png, 195/5600, 3.48%
# Processing 2780 Peg with friction 098L.png, 196/5600, 3.5%
# Processing 2780 Peg with friction 098R.png, 197/5600, 3.52%
# Processing 2780 Peg with friction 099L.png, 198/5600, 3.54%
# Processing 2780 Peg with friction 099R.png, 199/5600, 3.55%
# Processing 2780 Peg with friction 100L.png, 200/5600, 3.57%
# Processing 2780 Peg with friction 100R.png, 201/5600, 3.59%
# Processing 2780 Peg with friction 101L.png, 202/5600, 3.61%
# Processing 2780 Peg with friction 101R.png, 203/5600, 3.62%
# Processing 2780 Peg with friction 102L.png, 204/5600, 3.64%
# Processing 2780 Peg with friction 102R.png, 205/5600, 3.66%
# Processing 2780 Peg with friction 103L.png, 206/5600, 3.68%
# Processing 2780 Peg with friction 103R.png, 207/5600, 3.7%
# Processing 2780 Peg with friction 104L.png, 208/5600, 3.71%
# Processing 2780 Peg with friction 104R.png, 209/5600, 3.73%
# Processing 2780 Peg with friction 105L.png, 210/5600, 3.75%
# Processing 2780 Peg with friction 105R.png, 211/5600, 3.77%
# Processing 2780 Peg with friction 106L.png, 212/5600, 3.79%
# Processing 2780 Peg with friction 106R.png, 213/5600, 3.8%
# Processing 2780 Peg with friction 107L.png, 214/5600, 3.82%
# Processing 2780 Peg with friction 107R.png, 215/5600, 3.84%
# Processing 2780 Peg with friction 108L.png, 216/5600, 3.86%
# Processing 2780 Peg with friction 108R.png, 217/5600, 3.88%
# Processing 2780 Peg with friction 109L.png, 218/5600, 3.89%
# Processing 2780 Peg with friction 109R.png, 219/5600, 3.91%
# Processing 2780 Peg with friction 110L.png, 220/5600, 3.93%
# Processing 2780 Peg with friction 110R.png, 221/5600, 3.95%
# Processing 2780 Peg with friction 111L.png, 222/5600, 3.96%
# Processing 2780 Peg with friction 111R.png, 223/5600, 3.98%
# Processing 2780 Peg with friction 112L.png, 224/5600, 4.0%
# Processing 2780 Peg with friction 112R.png, 225/5600, 4.02%
# Processing 2780 Peg with friction 113L.png, 226/5600, 4.04%
# Processing 2780 Peg with friction 113R.png, 227/5600, 4.05%
# Processing 2780 Peg with friction 114L.png, 228/5600, 4.07%
# Processing 2780 Peg with friction 114R.png, 229/5600, 4.09%
# Processing 2780 Peg with friction 115L.png, 230/5600, 4.11%
# Processing 2780 Peg with friction 115R.png, 231/5600, 4.12%
# Processing 2780 Peg with friction 116L.png, 232/5600, 4.14%
# Processing 2780 Peg with friction 116R.png, 233/5600, 4.16%
# Processing 2780 Peg with friction 117L.png, 234/5600, 4.18%
# Processing 2780 Peg with friction 117R.png, 235/5600, 4.2%
# Processing 2780 Peg with friction 118L.png, 236/5600, 4.21%
# Processing 2780 Peg with friction 118R.png, 237/5600, 4.23%
# Processing 2780 Peg with friction 119L.png, 238/5600, 4.25%
# Processing 2780 Peg with friction 119R.png, 239/5600, 4.27%
# Processing 2780 Peg with friction 120L.png, 240/5600, 4.29%
# Processing 2780 Peg with friction 120R.png, 241/5600, 4.3%
# Processing 2780 Peg with friction 121L.png, 242/5600, 4.32%
# Processing 2780 Peg with friction 121R.png, 243/5600, 4.34%
# Processing 2780 Peg with friction 122L.png, 244/5600, 4.36%
# Processing 2780 Peg with friction 122R.png, 245/5600, 4.38%
# Processing 2780 Peg with friction 123L.png, 246/5600, 4.39%
# Processing 2780 Peg with friction 123R.png, 247/5600, 4.41%
# Processing 2780 Peg with friction 124L.png, 248/5600, 4.43%
# Processing 2780 Peg with friction 124R.png, 249/5600, 4.45%
# Processing 2780 Peg with friction 125L.png, 250/5600, 4.46%
# Processing 2780 Peg with friction 125R.png, 251/5600, 4.48%
# Processing 2780 Peg with friction 126L.png, 252/5600, 4.5%
# Processing 2780 Peg with friction 126R.png, 253/5600, 4.52%
# Processing 2780 Peg with friction 127L.png, 254/5600, 4.54%
# Processing 2780 Peg with friction 127R.png, 255/5600, 4.55%
# Processing 2780 Peg with friction 128L.png, 256/5600, 4.57%
# Processing 2780 Peg with friction 128R.png, 257/5600, 4.59%
# Processing 2780 Peg with friction 129L.png, 258/5600, 4.61%
# Processing 2780 Peg with friction 129R.png, 259/5600, 4.62%
# Processing 2780 Peg with friction 130L.png, 260/5600, 4.64%
# Processing 2780 Peg with friction 130R.png, 261/5600, 4.66%
# Processing 2780 Peg with friction 131L.png, 262/5600, 4.68%
# Processing 2780 Peg with friction 131R.png, 263/5600, 4.7%
# Processing 2780 Peg with friction 132L.png, 264/5600, 4.71%
# Processing 2780 Peg with friction 132R.png, 265/5600, 4.73%
# Processing 2780 Peg with friction 133L.png, 266/5600, 4.75%
# Processing 2780 Peg with friction 133R.png, 267/5600, 4.77%
# Processing 2780 Peg with friction 134L.png, 268/5600, 4.79%
# Processing 2780 Peg with friction 134R.png, 269/5600, 4.8%
# Processing 2780 Peg with friction 135L.png, 270/5600, 4.82%
# Processing 2780 Peg with friction 135R.png, 271/5600, 4.84%
# Processing 2780 Peg with friction 136L.png, 272/5600, 4.86%
# Processing 2780 Peg with friction 136R.png, 273/5600, 4.88%
# Processing 2780 Peg with friction 137L.png, 274/5600, 4.89%
# Processing 2780 Peg with friction 137R.png, 275/5600, 4.91%
# Processing 2780 Peg with friction 138L.png, 276/5600, 4.93%
# Processing 2780 Peg with friction 138R.png, 277/5600, 4.95%
# Processing 2780 Peg with friction 139L.png, 278/5600, 4.96%
# Processing 2780 Peg with friction 139R.png, 279/5600, 4.98%
# Processing 2780 Peg with friction 140L.png, 280/5600, 5.0%
# Processing 2780 Peg with friction 140R.png, 281/5600, 5.02%
# Processing 2780 Peg with friction 141L.png, 282/5600, 5.04%
# Processing 2780 Peg with friction 141R.png, 283/5600, 5.05%
# Processing 2780 Peg with friction 142L.png, 284/5600, 5.07%
# Processing 2780 Peg with friction 142R.png, 285/5600, 5.09%
# Processing 2780 Peg with friction 143L.png, 286/5600, 5.11%
# Processing 2780 Peg with friction 143R.png, 287/5600, 5.12%
# Processing 2780 Peg with friction 144L.png, 288/5600, 5.14%
# Processing 2780 Peg with friction 144R.png, 289/5600, 5.16%
# Processing 2780 Peg with friction 145L.png, 290/5600, 5.18%
# Processing 2780 Peg with friction 145R.png, 291/5600, 5.2%
# Processing 2780 Peg with friction 146L.png, 292/5600, 5.21%
# Processing 2780 Peg with friction 146R.png, 293/5600, 5.23%
# Processing 2780 Peg with friction 147L.png, 294/5600, 5.25%
# Processing 2780 Peg with friction 147R.png, 295/5600, 5.27%
# Processing 2780 Peg with friction 148L.png, 296/5600, 5.29%
# Processing 2780 Peg with friction 148R.png, 297/5600, 5.3%
# Processing 2780 Peg with friction 149L.png, 298/5600, 5.32%
# Processing 2780 Peg with friction 149R.png, 299/5600, 5.34%
# Processing 2780 Peg with friction 150L.png, 300/5600, 5.36%
# Processing 2780 Peg with friction 150R.png, 301/5600, 5.38%
# Processing 2780 Peg with friction 151L.png, 302/5600, 5.39%
# Processing 2780 Peg with friction 151R.png, 303/5600, 5.41%
# Processing 2780 Peg with friction 152L.png, 304/5600, 5.43%
# Processing 2780 Peg with friction 152R.png, 305/5600, 5.45%
# Processing 2780 Peg with friction 153L.png, 306/5600, 5.46%
# Processing 2780 Peg with friction 153R.png, 307/5600, 5.48%
# Processing 2780 Peg with friction 154L.png, 308/5600, 5.5%
# Processing 2780 Peg with friction 154R.png, 309/5600, 5.52%
# Processing 2780 Peg with friction 155L.png, 310/5600, 5.54%
# Processing 2780 Peg with friction 155R.png, 311/5600, 5.55%
# Processing 2780 Peg with friction 156L.png, 312/5600, 5.57%
# Processing 2780 Peg with friction 156R.png, 313/5600, 5.59%
# Processing 2780 Peg with friction 157L.png, 314/5600, 5.61%
# Processing 2780 Peg with friction 157R.png, 315/5600, 5.62%
# Processing 2780 Peg with friction 158L.png, 316/5600, 5.64%
# Processing 2780 Peg with friction 158R.png, 317/5600, 5.66%
# Processing 2780 Peg with friction 159L.png, 318/5600, 5.68%
# Processing 2780 Peg with friction 159R.png, 319/5600, 5.7%
# Processing 2780 Peg with friction 160L.png, 320/5600, 5.71%
# Processing 2780 Peg with friction 160R.png, 321/5600, 5.73%
# Processing 2780 Peg with friction 161L.png, 322/5600, 5.75%
# Processing 2780 Peg with friction 161R.png, 323/5600, 5.77%
# Processing 2780 Peg with friction 162L.png, 324/5600, 5.79%
# Processing 2780 Peg with friction 162R.png, 325/5600, 5.8%
# Processing 2780 Peg with friction 163L.png, 326/5600, 5.82%
# Processing 2780 Peg with friction 163R.png, 327/5600, 5.84%
# Processing 2780 Peg with friction 164L.png, 328/5600, 5.86%
# Processing 2780 Peg with friction 164R.png, 329/5600, 5.88%
# Processing 2780 Peg with friction 165L.png, 330/5600, 5.89%
# Processing 2780 Peg with friction 165R.png, 331/5600, 5.91%
# Processing 2780 Peg with friction 166L.png, 332/5600, 5.93%
# Processing 2780 Peg with friction 166R.png, 333/5600, 5.95%
# Processing 2780 Peg with friction 167L.png, 334/5600, 5.96%
# Processing 2780 Peg with friction 167R.png, 335/5600, 5.98%
# Processing 2780 Peg with friction 168L.png, 336/5600, 6.0%
# Processing 2780 Peg with friction 168R.png, 337/5600, 6.02%
# Processing 2780 Peg with friction 169L.png, 338/5600, 6.04%
# Processing 2780 Peg with friction 169R.png, 339/5600, 6.05%
# Processing 2780 Peg with friction 170L.png, 340/5600, 6.07%
# Processing 2780 Peg with friction 170R.png, 341/5600, 6.09%
# Processing 2780 Peg with friction 171L.png, 342/5600, 6.11%
# Processing 2780 Peg with friction 171R.png, 343/5600, 6.12%
# Processing 2780 Peg with friction 172L.png, 344/5600, 6.14%
# Processing 2780 Peg with friction 172R.png, 345/5600, 6.16%
# Processing 2780 Peg with friction 173L.png, 346/5600, 6.18%
# Processing 2780 Peg with friction 173R.png, 347/5600, 6.2%
# Processing 2780 Peg with friction 174L.png, 348/5600, 6.21%
# Processing 2780 Peg with friction 174R.png, 349/5600, 6.23%
# Processing 2780 Peg with friction 175L.png, 350/5600, 6.25%
# Processing 2780 Peg with friction 175R.png, 351/5600, 6.27%
# Processing 2780 Peg with friction 176L.png, 352/5600, 6.29%
# Processing 2780 Peg with friction 176R.png, 353/5600, 6.3%
# Processing 2780 Peg with friction 177L.png, 354/5600, 6.32%
# Processing 2780 Peg with friction 177R.png, 355/5600, 6.34%
# Processing 2780 Peg with friction 178L.png, 356/5600, 6.36%
# Processing 2780 Peg with friction 178R.png, 357/5600, 6.38%
# Processing 2780 Peg with friction 179L.png, 358/5600, 6.39%
# Processing 2780 Peg with friction 179R.png, 359/5600, 6.41%
# Processing 2780 Peg with friction 180L.png, 360/5600, 6.43%
# Processing 2780 Peg with friction 180R.png, 361/5600, 6.45%
# Processing 2780 Peg with friction 181L.png, 362/5600, 6.46%
# Processing 2780 Peg with friction 181R.png, 363/5600, 6.48%
# Processing 2780 Peg with friction 182L.png, 364/5600, 6.5%
# Processing 2780 Peg with friction 182R.png, 365/5600, 6.52%
# Processing 2780 Peg with friction 183L.png, 366/5600, 6.54%
# Processing 2780 Peg with friction 183R.png, 367/5600, 6.55%
# Processing 2780 Peg with friction 184L.png, 368/5600, 6.57%
# Processing 2780 Peg with friction 184R.png, 369/5600, 6.59%
# Processing 2780 Peg with friction 185L.png, 370/5600, 6.61%
# Processing 2780 Peg with friction 185R.png, 371/5600, 6.62%
# Processing 2780 Peg with friction 186L.png, 372/5600, 6.64%
# Processing 2780 Peg with friction 186R.png, 373/5600, 6.66%
# Processing 2780 Peg with friction 187L.png, 374/5600, 6.68%
# Processing 2780 Peg with friction 187R.png, 375/5600, 6.7%
# Processing 2780 Peg with friction 188L.png, 376/5600, 6.71%
# Processing 2780 Peg with friction 188R.png, 377/5600, 6.73%
# Processing 2780 Peg with friction 189L.png, 378/5600, 6.75%
# Processing 2780 Peg with friction 189R.png, 379/5600, 6.77%
# Processing 2780 Peg with friction 190L.png, 380/5600, 6.79%
# Processing 2780 Peg with friction 190R.png, 381/5600, 6.8%
# Processing 2780 Peg with friction 191L.png, 382/5600, 6.82%
# Processing 2780 Peg with friction 191R.png, 383/5600, 6.84%
# Processing 2780 Peg with friction 192L.png, 384/5600, 6.86%
# Processing 2780 Peg with friction 192R.png, 385/5600, 6.88%
# Processing 2780 Peg with friction 193L.png, 386/5600, 6.89%
# Processing 2780 Peg with friction 193R.png, 387/5600, 6.91%
# Processing 2780 Peg with friction 194L.png, 388/5600, 6.93%
# Processing 2780 Peg with friction 194R.png, 389/5600, 6.95%
# Processing 2780 Peg with friction 195L.png, 390/5600, 6.96%
# Processing 2780 Peg with friction 195R.png, 391/5600, 6.98%
# Processing 2780 Peg with friction 196L.png, 392/5600, 7.0%
# Processing 2780 Peg with friction 196R.png, 393/5600, 7.02%
# Processing 2780 Peg with friction 197L.png, 394/5600, 7.04%
# Processing 2780 Peg with friction 197R.png, 395/5600, 7.05%
# Processing 2780 Peg with friction 198L.png, 396/5600, 7.07%
# Processing 2780 Peg with friction 198R.png, 397/5600, 7.09%
# Processing 2780 Peg with friction 199L.png, 398/5600, 7.11%
# Processing 2780 Peg with friction 199R.png, 399/5600, 7.12%
# Processing 2780 Peg with friction 200L.png, 400/5600, 7.14%
# Processing 2780 Peg with friction 200R.png, 401/5600, 7.16%
# Processing 2780 Peg with friction 201L.png, 402/5600, 7.18%
# Processing 2780 Peg with friction 201R.png, 403/5600, 7.2%
# Processing 2780 Peg with friction 202L.png, 404/5600, 7.21%
# Processing 2780 Peg with friction 202R.png, 405/5600, 7.23%
# Processing 2780 Peg with friction 203L.png, 406/5600, 7.25%
# Processing 2780 Peg with friction 203R.png, 407/5600, 7.27%
# Processing 2780 Peg with friction 204L.png, 408/5600, 7.29%
# Processing 2780 Peg with friction 204R.png, 409/5600, 7.3%
# Processing 2780 Peg with friction 205L.png, 410/5600, 7.32%
# Processing 2780 Peg with friction 205R.png, 411/5600, 7.34%
# Processing 2780 Peg with friction 206L.png, 412/5600, 7.36%
# Processing 2780 Peg with friction 206R.png, 413/5600, 7.38%
# Processing 2780 Peg with friction 207L.png, 414/5600, 7.39%
# Processing 2780 Peg with friction 207R.png, 415/5600, 7.41%
# Processing 2780 Peg with friction 208L.png, 416/5600, 7.43%
# Processing 2780 Peg with friction 208R.png, 417/5600, 7.45%
# Processing 2780 Peg with friction 209L.png, 418/5600, 7.46%
# Processing 2780 Peg with friction 209R.png, 419/5600, 7.48%
# Processing 2780 Peg with friction 210L.png, 420/5600, 7.5%
# Processing 2780 Peg with friction 210R.png, 421/5600, 7.52%
# Processing 2780 Peg with friction 211L.png, 422/5600, 7.54%
# Processing 2780 Peg with friction 211R.png, 423/5600, 7.55%
# Processing 2780 Peg with friction 212L.png, 424/5600, 7.57%
# Processing 2780 Peg with friction 212R.png, 425/5600, 7.59%
# Processing 2780 Peg with friction 213L.png, 426/5600, 7.61%
# Processing 2780 Peg with friction 213R.png, 427/5600, 7.62%
# Processing 2780 Peg with friction 214L.png, 428/5600, 7.64%
# Processing 2780 Peg with friction 214R.png, 429/5600, 7.66%
# Processing 2780 Peg with friction 215L.png, 430/5600, 7.68%
# Processing 2780 Peg with friction 215R.png, 431/5600, 7.7%
# Processing 2780 Peg with friction 216L.png, 432/5600, 7.71%
# Processing 2780 Peg with friction 216R.png, 433/5600, 7.73%
# Processing 2780 Peg with friction 217L.png, 434/5600, 7.75%
# Processing 2780 Peg with friction 217R.png, 435/5600, 7.77%
# Processing 2780 Peg with friction 218L.png, 436/5600, 7.79%
# Processing 2780 Peg with friction 218R.png, 437/5600, 7.8%
# Processing 2780 Peg with friction 219L.png, 438/5600, 7.82%
# Processing 2780 Peg with friction 219R.png, 439/5600, 7.84%
# Processing 2780 Peg with friction 220L.png, 440/5600, 7.86%
# Processing 2780 Peg with friction 220R.png, 441/5600, 7.88%
# Processing 2780 Peg with friction 221L.png, 442/5600, 7.89%
# Processing 2780 Peg with friction 221R.png, 443/5600, 7.91%
# Processing 2780 Peg with friction 222L.png, 444/5600, 7.93%
# Processing 2780 Peg with friction 222R.png, 445/5600, 7.95%
# Processing 2780 Peg with friction 223L.png, 446/5600, 7.96%
# Processing 2780 Peg with friction 223R.png, 447/5600, 7.98%
# Processing 2780 Peg with friction 224L.png, 448/5600, 8.0%
# Processing 2780 Peg with friction 224R.png, 449/5600, 8.02%
# Processing 2780 Peg with friction 225L.png, 450/5600, 8.04%
# Processing 2780 Peg with friction 225R.png, 451/5600, 8.05%
# Processing 2780 Peg with friction 226L.png, 452/5600, 8.07%
# Processing 2780 Peg with friction 226R.png, 453/5600, 8.09%
# Processing 2780 Peg with friction 227L.png, 454/5600, 8.11%
# Processing 2780 Peg with friction 227R.png, 455/5600, 8.12%
# Processing 2780 Peg with friction 228L.png, 456/5600, 8.14%
# Processing 2780 Peg with friction 228R.png, 457/5600, 8.16%
# Processing 2780 Peg with friction 229L.png, 458/5600, 8.18%
# Processing 2780 Peg with friction 229R.png, 459/5600, 8.2%
# Processing 2780 Peg with friction 230L.png, 460/5600, 8.21%
# Processing 2780 Peg with friction 230R.png, 461/5600, 8.23%
# Processing 2780 Peg with friction 231L.png, 462/5600, 8.25%
# Processing 2780 Peg with friction 231R.png, 463/5600, 8.27%
# Processing 2780 Peg with friction 232L.png, 464/5600, 8.29%
# Processing 2780 Peg with friction 232R.png, 465/5600, 8.3%
# Processing 2780 Peg with friction 233L.png, 466/5600, 8.32%
# Processing 2780 Peg with friction 233R.png, 467/5600, 8.34%
# Processing 2780 Peg with friction 234L.png, 468/5600, 8.36%
# Processing 2780 Peg with friction 234R.png, 469/5600, 8.38%
# Processing 2780 Peg with friction 235L.png, 470/5600, 8.39%
# Processing 2780 Peg with friction 235R.png, 471/5600, 8.41%
# Processing 2780 Peg with friction 236L.png, 472/5600, 8.43%
# Processing 2780 Peg with friction 236R.png, 473/5600, 8.45%
# Processing 2780 Peg with friction 237L.png, 474/5600, 8.46%
# Processing 2780 Peg with friction 237R.png, 475/5600, 8.48%
# Processing 2780 Peg with friction 238L.png, 476/5600, 8.5%
# Processing 2780 Peg with friction 238R.png, 477/5600, 8.52%
# Processing 2780 Peg with friction 239L.png, 478/5600, 8.54%
# Processing 2780 Peg with friction 239R.png, 479/5600, 8.55%
# Processing 2780 Peg with friction 240L.png, 480/5600, 8.57%
# Processing 2780 Peg with friction 240R.png, 481/5600, 8.59%
# Processing 2780 Peg with friction 241L.png, 482/5600, 8.61%
# Processing 2780 Peg with friction 241R.png, 483/5600, 8.62%
# Processing 2780 Peg with friction 242L.png, 484/5600, 8.64%
# Processing 2780 Peg with friction 242R.png, 485/5600, 8.66%
# Processing 2780 Peg with friction 243L.png, 486/5600, 8.68%
# Processing 2780 Peg with friction 243R.png, 487/5600, 8.7%
# Processing 2780 Peg with friction 244L.png, 488/5600, 8.71%
# Processing 2780 Peg with friction 244R.png, 489/5600, 8.73%
# Processing 2780 Peg with friction 245L.png, 490/5600, 8.75%
# Processing 2780 Peg with friction 245R.png, 491/5600, 8.77%
# Processing 2780 Peg with friction 246L.png, 492/5600, 8.79%
# Processing 2780 Peg with friction 246R.png, 493/5600, 8.8%
# Processing 2780 Peg with friction 247L.png, 494/5600, 8.82%
# Processing 2780 Peg with friction 247R.png, 495/5600, 8.84%
# Processing 2780 Peg with friction 248L.png, 496/5600, 8.86%
# Processing 2780 Peg with friction 248R.png, 497/5600, 8.88%
# Processing 2780 Peg with friction 249L.png, 498/5600, 8.89%
# Processing 2780 Peg with friction 249R.png, 499/5600, 8.91%
# Processing 2780 Peg with friction 250L.png, 500/5600, 8.93%
# Processing 2780 Peg with friction 250R.png, 501/5600, 8.95%
# Processing 2780 Peg with friction 251L.png, 502/5600, 8.96%
# Processing 2780 Peg with friction 251R.png, 503/5600, 8.98%
# Processing 2780 Peg with friction 252L.png, 504/5600, 9.0%
# Processing 2780 Peg with friction 252R.png, 505/5600, 9.02%
# Processing 2780 Peg with friction 253L.png, 506/5600, 9.04%
# Processing 2780 Peg with friction 253R.png, 507/5600, 9.05%
# Processing 2780 Peg with friction 254L.png, 508/5600, 9.07%
# Processing 2780 Peg with friction 254R.png, 509/5600, 9.09%
# Processing 2780 Peg with friction 255L.png, 510/5600, 9.11%
# Processing 2780 Peg with friction 255R.png, 511/5600, 9.12%
# Processing 2780 Peg with friction 256L.png, 512/5600, 9.14%
# Processing 2780 Peg with friction 256R.png, 513/5600, 9.16%
# Processing 2780 Peg with friction 257L.png, 514/5600, 9.18%
# Processing 2780 Peg with friction 257R.png, 515/5600, 9.2%
# Processing 2780 Peg with friction 258L.png, 516/5600, 9.21%
# Processing 2780 Peg with friction 258R.png, 517/5600, 9.23%
# Processing 2780 Peg with friction 259L.png, 518/5600, 9.25%
# Processing 2780 Peg with friction 259R.png, 519/5600, 9.27%
# Processing 2780 Peg with friction 260L.png, 520/5600, 9.29%
# Processing 2780 Peg with friction 260R.png, 521/5600, 9.3%
# Processing 2780 Peg with friction 261L.png, 522/5600, 9.32%
# Processing 2780 Peg with friction 261R.png, 523/5600, 9.34%
# Processing 2780 Peg with friction 262L.png, 524/5600, 9.36%
# Processing 2780 Peg with friction 262R.png, 525/5600, 9.38%
# Processing 2780 Peg with friction 263L.png, 526/5600, 9.39%
# Processing 2780 Peg with friction 263R.png, 527/5600, 9.41%
# Processing 2780 Peg with friction 264L.png, 528/5600, 9.43%
# Processing 2780 Peg with friction 264R.png, 529/5600, 9.45%
# Processing 2780 Peg with friction 265L.png, 530/5600, 9.46%
# Processing 2780 Peg with friction 265R.png, 531/5600, 9.48%
# Processing 2780 Peg with friction 266L.png, 532/5600, 9.5%
# Processing 2780 Peg with friction 266R.png, 533/5600, 9.52%
# Processing 2780 Peg with friction 267L.png, 534/5600, 9.54%
# Processing 2780 Peg with friction 267R.png, 535/5600, 9.55%
# Processing 2780 Peg with friction 268L.png, 536/5600, 9.57%
# Processing 2780 Peg with friction 268R.png, 537/5600, 9.59%
# Processing 2780 Peg with friction 269L.png, 538/5600, 9.61%
# Processing 2780 Peg with friction 269R.png, 539/5600, 9.62%
# Processing 2780 Peg with friction 270L.png, 540/5600, 9.64%
# Processing 2780 Peg with friction 270R.png, 541/5600, 9.66%
# Processing 2780 Peg with friction 271L.png, 542/5600, 9.68%
# Processing 2780 Peg with friction 271R.png, 543/5600, 9.7%
# Processing 2780 Peg with friction 272L.png, 544/5600, 9.71%
# Processing 2780 Peg with friction 272R.png, 545/5600, 9.73%
# Processing 2780 Peg with friction 273L.png, 546/5600, 9.75%
# Processing 2780 Peg with friction 273R.png, 547/5600, 9.77%
# Processing 2780 Peg with friction 274L.png, 548/5600, 9.79%
# Processing 2780 Peg with friction 274R.png, 549/5600, 9.8%
# Processing 2780 Peg with friction 275L.png, 550/5600, 9.82%
# Processing 2780 Peg with friction 275R.png, 551/5600, 9.84%
# Processing 2780 Peg with friction 276L.png, 552/5600, 9.86%
# Processing 2780 Peg with friction 276R.png, 553/5600, 9.88%
# Processing 2780 Peg with friction 277L.png, 554/5600, 9.89%
# Processing 2780 Peg with friction 277R.png, 555/5600, 9.91%
# Processing 2780 Peg with friction 278L.png, 556/5600, 9.93%
# Processing 2780 Peg with friction 278R.png, 557/5600, 9.95%
# Processing 2780 Peg with friction 279L.png, 558/5600, 9.96%
# Processing 2780 Peg with friction 279R.png, 559/5600, 9.98%
# Processing 2780 Peg with friction 280L.png, 560/5600, 10.0%
# Processing 2780 Peg with friction 280R.png, 561/5600, 10.02%
# Processing 2780 Peg with friction 281L.png, 562/5600, 10.04%
# Processing 2780 Peg with friction 281R.png, 563/5600, 10.05%
# Processing 2780 Peg with friction 282L.png, 564/5600, 10.07%
# Processing 2780 Peg with friction 282R.png, 565/5600, 10.09%
# Processing 2780 Peg with friction 283L.png, 566/5600, 10.11%
# Processing 2780 Peg with friction 283R.png, 567/5600, 10.12%
# Processing 2780 Peg with friction 284L.png, 568/5600, 10.14%
# Processing 2780 Peg with friction 284R.png, 569/5600, 10.16%
# Processing 2780 Peg with friction 285L.png, 570/5600, 10.18%
# Processing 2780 Peg with friction 285R.png, 571/5600, 10.2%
# Processing 2780 Peg with friction 286L.png, 572/5600, 10.21%
# Processing 2780 Peg with friction 286R.png, 573/5600, 10.23%
# Processing 2780 Peg with friction 287L.png, 574/5600, 10.25%
# Processing 2780 Peg with friction 287R.png, 575/5600, 10.27%
# Processing 2780 Peg with friction 288L.png, 576/5600, 10.29%
# Processing 2780 Peg with friction 288R.png, 577/5600, 10.3%
# Processing 2780 Peg with friction 289L.png, 578/5600, 10.32%
# Processing 2780 Peg with friction 289R.png, 579/5600, 10.34%
# Processing 2780 Peg with friction 290L.png, 580/5600, 10.36%
# Processing 2780 Peg with friction 290R.png, 581/5600, 10.38%
# Processing 2780 Peg with friction 291L.png, 582/5600, 10.39%
# Processing 2780 Peg with friction 291R.png, 583/5600, 10.41%
# Processing 2780 Peg with friction 292L.png, 584/5600, 10.43%
# Processing 2780 Peg with friction 292R.png, 585/5600, 10.45%
# Processing 2780 Peg with friction 293L.png, 586/5600, 10.46%
# Processing 2780 Peg with friction 293R.png, 587/5600, 10.48%
# Processing 2780 Peg with friction 294L.png, 588/5600, 10.5%
# Processing 2780 Peg with friction 294R.png, 589/5600, 10.52%
# Processing 2780 Peg with friction 295L.png, 590/5600, 10.54%
# Processing 2780 Peg with friction 295R.png, 591/5600, 10.55%
# Processing 2780 Peg with friction 296L.png, 592/5600, 10.57%
# Processing 2780 Peg with friction 296R.png, 593/5600, 10.59%
# Processing 2780 Peg with friction 297L.png, 594/5600, 10.61%
# Processing 2780 Peg with friction 297R.png, 595/5600, 10.62%
# Processing 2780 Peg with friction 298L.png, 596/5600, 10.64%
# Processing 2780 Peg with friction 298R.png, 597/5600, 10.66%
# Processing 2780 Peg with friction 299L.png, 598/5600, 10.68%
# Processing 2780 Peg with friction 299R.png, 599/5600, 10.7%
# Processing 2780 Peg with friction 300L.png, 600/5600, 10.71%
# Processing 2780 Peg with friction 300R.png, 601/5600, 10.73%
# Processing 2780 Peg with friction 301L.png, 602/5600, 10.75%
# Processing 2780 Peg with friction 301R.png, 603/5600, 10.77%
# Processing 2780 Peg with friction 302L.png, 604/5600, 10.79%
# Processing 2780 Peg with friction 302R.png, 605/5600, 10.8%
# Processing 2780 Peg with friction 303L.png, 606/5600, 10.82%
# Processing 2780 Peg with friction 303R.png, 607/5600, 10.84%
# Processing 2780 Peg with friction 304L.png, 608/5600, 10.86%
# Processing 2780 Peg with friction 304R.png, 609/5600, 10.88%
# Processing 2780 Peg with friction 305L.png, 610/5600, 10.89%
# Processing 2780 Peg with friction 305R.png, 611/5600, 10.91%
# Processing 2780 Peg with friction 306L.png, 612/5600, 10.93%
# Processing 2780 Peg with friction 306R.png, 613/5600, 10.95%
# Processing 2780 Peg with friction 307L.png, 614/5600, 10.96%
# Processing 2780 Peg with friction 307R.png, 615/5600, 10.98%
# Processing 2780 Peg with friction 308L.png, 616/5600, 11.0%
# Processing 2780 Peg with friction 308R.png, 617/5600, 11.02%
# Processing 2780 Peg with friction 309L.png, 618/5600, 11.04%
# Processing 2780 Peg with friction 309R.png, 619/5600, 11.05%
# Processing 2780 Peg with friction 310L.png, 620/5600, 11.07%
# Processing 2780 Peg with friction 310R.png, 621/5600, 11.09%
# Processing 2780 Peg with friction 311L.png, 622/5600, 11.11%
# Processing 2780 Peg with friction 311R.png, 623/5600, 11.12%
# Processing 2780 Peg with friction 312L.png, 624/5600, 11.14%
# Processing 2780 Peg with friction 312R.png, 625/5600, 11.16%
# Processing 2780 Peg with friction 313L.png, 626/5600, 11.18%
# Processing 2780 Peg with friction 313R.png, 627/5600, 11.2%
# Processing 2780 Peg with friction 314L.png, 628/5600, 11.21%
# Processing 2780 Peg with friction 314R.png, 629/5600, 11.23%
# Processing 2780 Peg with friction 315L.png, 630/5600, 11.25%
# Processing 2780 Peg with friction 315R.png, 631/5600, 11.27%
# Processing 2780 Peg with friction 316L.png, 632/5600, 11.29%
# Processing 2780 Peg with friction 316R.png, 633/5600, 11.3%
# Processing 2780 Peg with friction 317L.png, 634/5600, 11.32%
# Processing 2780 Peg with friction 317R.png, 635/5600, 11.34%
# Processing 2780 Peg with friction 318L.png, 636/5600, 11.36%
# Processing 2780 Peg with friction 318R.png, 637/5600, 11.38%
# Processing 2780 Peg with friction 319L.png, 638/5600, 11.39%
# Processing 2780 Peg with friction 319R.png, 639/5600, 11.41%
# Processing 2780 Peg with friction 320L.png, 640/5600, 11.43%
# Processing 2780 Peg with friction 320R.png, 641/5600, 11.45%
# Processing 2780 Peg with friction 321L.png, 642/5600, 11.46%
# Processing 2780 Peg with friction 321R.png, 643/5600, 11.48%
# Processing 2780 Peg with friction 322L.png, 644/5600, 11.5%
# Processing 2780 Peg with friction 322R.png, 645/5600, 11.52%
# Processing 2780 Peg with friction 323L.png, 646/5600, 11.54%
# Processing 2780 Peg with friction 323R.png, 647/5600, 11.55%
# Processing 2780 Peg with friction 324L.png, 648/5600, 11.57%
# Processing 2780 Peg with friction 324R.png, 649/5600, 11.59%
# Processing 2780 Peg with friction 325L.png, 650/5600, 11.61%
# Processing 2780 Peg with friction 325R.png, 651/5600, 11.62%
# Processing 2780 Peg with friction 326L.png, 652/5600, 11.64%
# Processing 2780 Peg with friction 326R.png, 653/5600, 11.66%
# Processing 2780 Peg with friction 327L.png, 654/5600, 11.68%
# Processing 2780 Peg with friction 327R.png, 655/5600, 11.7%
# Processing 2780 Peg with friction 328L.png, 656/5600, 11.71%
# Processing 2780 Peg with friction 328R.png, 657/5600, 11.73%
# Processing 2780 Peg with friction 329L.png, 658/5600, 11.75%
# Processing 2780 Peg with friction 329R.png, 659/5600, 11.77%
# Processing 2780 Peg with friction 330L.png, 660/5600, 11.79%
# Processing 2780 Peg with friction 330R.png, 661/5600, 11.8%
# Processing 2780 Peg with friction 331L.png, 662/5600, 11.82%
# Processing 2780 Peg with friction 331R.png, 663/5600, 11.84%
# Processing 2780 Peg with friction 332L.png, 664/5600, 11.86%
# Processing 2780 Peg with friction 332R.png, 665/5600, 11.88%
# Processing 2780 Peg with friction 333L.png, 666/5600, 11.89%
# Processing 2780 Peg with friction 333R.png, 667/5600, 11.91%
# Processing 2780 Peg with friction 334L.png, 668/5600, 11.93%
# Processing 2780 Peg with friction 334R.png, 669/5600, 11.95%
# Processing 2780 Peg with friction 335L.png, 670/5600, 11.96%
# Processing 2780 Peg with friction 335R.png, 671/5600, 11.98%
# Processing 2780 Peg with friction 336L.png, 672/5600, 12.0%
# Processing 2780 Peg with friction 336R.png, 673/5600, 12.02%
# Processing 2780 Peg with friction 337L.png, 674/5600, 12.04%
# Processing 2780 Peg with friction 337R.png, 675/5600, 12.05%
# Processing 2780 Peg with friction 338L.png, 676/5600, 12.07%
# Processing 2780 Peg with friction 338R.png, 677/5600, 12.09%
# Processing 2780 Peg with friction 339L.png, 678/5600, 12.11%
# Processing 2780 Peg with friction 339R.png, 679/5600, 12.12%
# Processing 2780 Peg with friction 340L.png, 680/5600, 12.14%
# Processing 2780 Peg with friction 340R.png, 681/5600, 12.16%
# Processing 2780 Peg with friction 341L.png, 682/5600, 12.18%
# Processing 2780 Peg with friction 341R.png, 683/5600, 12.2%
# Processing 2780 Peg with friction 342L.png, 684/5600, 12.21%
# Processing 2780 Peg with friction 342R.png, 685/5600, 12.23%
# Processing 2780 Peg with friction 343L.png, 686/5600, 12.25%
# Processing 2780 Peg with friction 343R.png, 687/5600, 12.27%
# Processing 2780 Peg with friction 344L.png, 688/5600, 12.29%
# Processing 2780 Peg with friction 344R.png, 689/5600, 12.3%
# Processing 2780 Peg with friction 345L.png, 690/5600, 12.32%
# Processing 2780 Peg with friction 345R.png, 691/5600, 12.34%
# Processing 2780 Peg with friction 346L.png, 692/5600, 12.36%
# Processing 2780 Peg with friction 346R.png, 693/5600, 12.38%
# Processing 2780 Peg with friction 347L.png, 694/5600, 12.39%
# Processing 2780 Peg with friction 347R.png, 695/5600, 12.41%
# Processing 2780 Peg with friction 348L.png, 696/5600, 12.43%
# Processing 2780 Peg with friction 348R.png, 697/5600, 12.45%
# Processing 2780 Peg with friction 349L.png, 698/5600, 12.46%
# Processing 2780 Peg with friction 349R.png, 699/5600, 12.48%
# Processing 2780 Peg with friction 350L.png, 700/5600, 12.5%
# Processing 2780 Peg with friction 350R.png, 701/5600, 12.52%
# Processing 2780 Peg with friction 351L.png, 702/5600, 12.54%
# Processing 2780 Peg with friction 351R.png, 703/5600, 12.55%
# Processing 2780 Peg with friction 352L.png, 704/5600, 12.57%
# Processing 2780 Peg with friction 352R.png, 705/5600, 12.59%
# Processing 2780 Peg with friction 353L.png, 706/5600, 12.61%
# Processing 2780 Peg with friction 353R.png, 707/5600, 12.62%
# Processing 2780 Peg with friction 354L.png, 708/5600, 12.64%
# Processing 2780 Peg with friction 354R.png, 709/5600, 12.66%
# Processing 2780 Peg with friction 355L.png, 710/5600, 12.68%
# Processing 2780 Peg with friction 355R.png, 711/5600, 12.7%
# Processing 2780 Peg with friction 356L.png, 712/5600, 12.71%
# Processing 2780 Peg with friction 356R.png, 713/5600, 12.73%
# Processing 2780 Peg with friction 357L.png, 714/5600, 12.75%
# Processing 2780 Peg with friction 357R.png, 715/5600, 12.77%
# Processing 2780 Peg with friction 358L.png, 716/5600, 12.79%
# Processing 2780 Peg with friction 358R.png, 717/5600, 12.8%
# Processing 2780 Peg with friction 359L.png, 718/5600, 12.82%
# Processing 2780 Peg with friction 359R.png, 719/5600, 12.84%
# Processing 2780 Peg with friction 360L.png, 720/5600, 12.86%
# Processing 2780 Peg with friction 360R.png, 721/5600, 12.88%
# Processing 2780 Peg with friction 361L.png, 722/5600, 12.89%
# Processing 2780 Peg with friction 361R.png, 723/5600, 12.91%
# Processing 2780 Peg with friction 362L.png, 724/5600, 12.93%
# Processing 2780 Peg with friction 362R.png, 725/5600, 12.95%
# Processing 2780 Peg with friction 363L.png, 726/5600, 12.96%
# Processing 2780 Peg with friction 363R.png, 727/5600, 12.98%
# Processing 2780 Peg with friction 364L.png, 728/5600, 13.0%
# Processing 2780 Peg with friction 364R.png, 729/5600, 13.02%
# Processing 2780 Peg with friction 365L.png, 730/5600, 13.04%
# Processing 2780 Peg with friction 365R.png, 731/5600, 13.05%
# Processing 2780 Peg with friction 366L.png, 732/5600, 13.07%
# Processing 2780 Peg with friction 366R.png, 733/5600, 13.09%
# Processing 2780 Peg with friction 367L.png, 734/5600, 13.11%
# Processing 2780 Peg with friction 367R.png, 735/5600, 13.12%
# Processing 2780 Peg with friction 368L.png, 736/5600, 13.14%
# Processing 2780 Peg with friction 368R.png, 737/5600, 13.16%
# Processing 2780 Peg with friction 369L.png, 738/5600, 13.18%
# Processing 2780 Peg with friction 369R.png, 739/5600, 13.2%
# Processing 2780 Peg with friction 370L.png, 740/5600, 13.21%
# Processing 2780 Peg with friction 370R.png, 741/5600, 13.23%
# Processing 2780 Peg with friction 371L.png, 742/5600, 13.25%
# Processing 2780 Peg with friction 371R.png, 743/5600, 13.27%
# Processing 2780 Peg with friction 372L.png, 744/5600, 13.29%
# Processing 2780 Peg with friction 372R.png, 745/5600, 13.3%
# Processing 2780 Peg with friction 373L.png, 746/5600, 13.32%
# Processing 2780 Peg with friction 373R.png, 747/5600, 13.34%
# Processing 2780 Peg with friction 374L.png, 748/5600, 13.36%
# Processing 2780 Peg with friction 374R.png, 749/5600, 13.38%
# Processing 2780 Peg with friction 375L.png, 750/5600, 13.39%
# Processing 2780 Peg with friction 375R.png, 751/5600, 13.41%
# Processing 2780 Peg with friction 376L.png, 752/5600, 13.43%
# Processing 2780 Peg with friction 376R.png, 753/5600, 13.45%
# Processing 2780 Peg with friction 377L.png, 754/5600, 13.46%
# Processing 2780 Peg with friction 377R.png, 755/5600, 13.48%
# Processing 2780 Peg with friction 378L.png, 756/5600, 13.5%
# Processing 2780 Peg with friction 378R.png, 757/5600, 13.52%
# Processing 2780 Peg with friction 379L.png, 758/5600, 13.54%
# Processing 2780 Peg with friction 379R.png, 759/5600, 13.55%
# Processing 2780 Peg with friction 380L.png, 760/5600, 13.57%
# Processing 2780 Peg with friction 380R.png, 761/5600, 13.59%
# Processing 2780 Peg with friction 381L.png, 762/5600, 13.61%
# Processing 2780 Peg with friction 381R.png, 763/5600, 13.63%
# Processing 2780 Peg with friction 382L.png, 764/5600, 13.64%
# Processing 2780 Peg with friction 382R.png, 765/5600, 13.66%
# Processing 2780 Peg with friction 383L.png, 766/5600, 13.68%
# Processing 2780 Peg with friction 383R.png, 767/5600, 13.7%
# Processing 2780 Peg with friction 384L.png, 768/5600, 13.71%
# Processing 2780 Peg with friction 384R.png, 769/5600, 13.73%
# Processing 2780 Peg with friction 385L.png, 770/5600, 13.75%
# Processing 2780 Peg with friction 385R.png, 771/5600, 13.77%
# Processing 2780 Peg with friction 386L.png, 772/5600, 13.79%
# Processing 2780 Peg with friction 386R.png, 773/5600, 13.8%
# Processing 2780 Peg with friction 387L.png, 774/5600, 13.82%
# Processing 2780 Peg with friction 387R.png, 775/5600, 13.84%
# Processing 2780 Peg with friction 388L.png, 776/5600, 13.86%
# Processing 2780 Peg with friction 388R.png, 777/5600, 13.88%
# Processing 2780 Peg with friction 389L.png, 778/5600, 13.89%
# Processing 2780 Peg with friction 389R.png, 779/5600, 13.91%
# Processing 2780 Peg with friction 390L.png, 780/5600, 13.93%
# Processing 2780 Peg with friction 390R.png, 781/5600, 13.95%
# Processing 2780 Peg with friction 391L.png, 782/5600, 13.96%
# Processing 2780 Peg with friction 391R.png, 783/5600, 13.98%
# Processing 2780 Peg with friction 392L.png, 784/5600, 14.0%
# Processing 2780 Peg with friction 392R.png, 785/5600, 14.02%
# Processing 2780 Peg with friction 393L.png, 786/5600, 14.04%
# Processing 2780 Peg with friction 393R.png, 787/5600, 14.05%
# Processing 2780 Peg with friction 394L.png, 788/5600, 14.07%
# Processing 2780 Peg with friction 394R.png, 789/5600, 14.09%
# Processing 2780 Peg with friction 395L.png, 790/5600, 14.11%
# Processing 2780 Peg with friction 395R.png, 791/5600, 14.12%
# Processing 2780 Peg with friction 396L.png, 792/5600, 14.14%
# Processing 2780 Peg with friction 396R.png, 793/5600, 14.16%
# Processing 2780 Peg with friction 397L.png, 794/5600, 14.18%
# Processing 2780 Peg with friction 397R.png, 795/5600, 14.2%
# Processing 2780 Peg with friction 398L.png, 796/5600, 14.21%
# Processing 2780 Peg with friction 398R.png, 797/5600, 14.23%
# Processing 2780 Peg with friction 399L.png, 798/5600, 14.25%
# ...
# Processing 99301 roof tile inside 3x3 279L.png, 5358/5600, 95.68%
# Processing 99301 roof tile inside 3x3 279R.png, 5359/5600, 95.7%
# Processing 99301 roof tile inside 3x3 280L.png, 5360/5600, 95.71%
# Processing 99301 roof tile inside 3x3 280R.png, 5361/5600, 95.73%
# Processing 99301 roof tile inside 3x3 281L.png, 5362/5600, 95.75%
# Processing 99301 roof tile inside 3x3 281R.png, 5363/5600, 95.77%
# Processing 99301 roof tile inside 3x3 282L.png, 5364/5600, 95.79%
# Processing 99301 roof tile inside 3x3 282R.png, 5365/5600, 95.8%
# Processing 99301 roof tile inside 3x3 283L.png, 5366/5600, 95.82%
# Processing 99301 roof tile inside 3x3 283R.png, 5367/5600, 95.84%
# Processing 99301 roof tile inside 3x3 284L.png, 5368/5600, 95.86%
# Processing 99301 roof tile inside 3x3 284R.png, 5369/5600, 95.88%
# Processing 99301 roof tile inside 3x3 285L.png, 5370/5600, 95.89%
# Processing 99301 roof tile inside 3x3 285R.png, 5371/5600, 95.91%
# Processing 99301 roof tile inside 3x3 286L.png, 5372/5600, 95.93%
# Processing 99301 roof tile inside 3x3 286R.png, 5373/5600, 95.95%
# Processing 99301 roof tile inside 3x3 287L.png, 5374/5600, 95.96%
# Processing 99301 roof tile inside 3x3 287R.png, 5375/5600, 95.98%
# Processing 99301 roof tile inside 3x3 288L.png, 5376/5600, 96.0%
# Processing 99301 roof tile inside 3x3 288R.png, 5377/5600, 96.02%
# Processing 99301 roof tile inside 3x3 289L.png, 5378/5600, 96.04%
# Processing 99301 roof tile inside 3x3 289R.png, 5379/5600, 96.05%
# Processing 99301 roof tile inside 3x3 290L.png, 5380/5600, 96.07%
# Processing 99301 roof tile inside 3x3 290R.png, 5381/5600, 96.09%
# Processing 99301 roof tile inside 3x3 291L.png, 5382/5600, 96.11%
# Processing 99301 roof tile inside 3x3 291R.png, 5383/5600, 96.12%
# Processing 99301 roof tile inside 3x3 292L.png, 5384/5600, 96.14%
# Processing 99301 roof tile inside 3x3 292R.png, 5385/5600, 96.16%
# Processing 99301 roof tile inside 3x3 293L.png, 5386/5600, 96.18%
# Processing 99301 roof tile inside 3x3 293R.png, 5387/5600, 96.2%
# Processing 99301 roof tile inside 3x3 294L.png, 5388/5600, 96.21%
# Processing 99301 roof tile inside 3x3 294R.png, 5389/5600, 96.23%
# Processing 99301 roof tile inside 3x3 295L.png, 5390/5600, 96.25%
# Processing 99301 roof tile inside 3x3 295R.png, 5391/5600, 96.27%
# Processing 99301 roof tile inside 3x3 296L.png, 5392/5600, 96.29%
# Processing 99301 roof tile inside 3x3 296R.png, 5393/5600, 96.3%
# Processing 99301 roof tile inside 3x3 297L.png, 5394/5600, 96.32%
# Processing 99301 roof tile inside 3x3 297R.png, 5395/5600, 96.34%
# Processing 99301 roof tile inside 3x3 298L.png, 5396/5600, 96.36%
# Processing 99301 roof tile inside 3x3 298R.png, 5397/5600, 96.38%
# Processing 99301 roof tile inside 3x3 299L.png, 5398/5600, 96.39%
# Processing 99301 roof tile inside 3x3 299R.png, 5399/5600, 96.41%
# Processing 99301 roof tile inside 3x3 300L.png, 5400/5600, 96.43%
# Processing 99301 roof tile inside 3x3 300R.png, 5401/5600, 96.45%
# Processing 99301 roof tile inside 3x3 301L.png, 5402/5600, 96.46%
# Processing 99301 roof tile inside 3x3 301R.png, 5403/5600, 96.48%
# Processing 99301 roof tile inside 3x3 302L.png, 5404/5600, 96.5%
# Processing 99301 roof tile inside 3x3 302R.png, 5405/5600, 96.52%
# Processing 99301 roof tile inside 3x3 303L.png, 5406/5600, 96.54%
# Processing 99301 roof tile inside 3x3 303R.png, 5407/5600, 96.55%
# Processing 99301 roof tile inside 3x3 304L.png, 5408/5600, 96.57%
# Processing 99301 roof tile inside 3x3 304R.png, 5409/5600, 96.59%
# Processing 99301 roof tile inside 3x3 305L.png, 5410/5600, 96.61%
# Processing 99301 roof tile inside 3x3 305R.png, 5411/5600, 96.62%
# Processing 99301 roof tile inside 3x3 306L.png, 5412/5600, 96.64%
# Processing 99301 roof tile inside 3x3 306R.png, 5413/5600, 96.66%
# Processing 99301 roof tile inside 3x3 307L.png, 5414/5600, 96.68%
# Processing 99301 roof tile inside 3x3 307R.png, 5415/5600, 96.7%
# Processing 99301 roof tile inside 3x3 308L.png, 5416/5600, 96.71%
# Processing 99301 roof tile inside 3x3 308R.png, 5417/5600, 96.73%
# Processing 99301 roof tile inside 3x3 309L.png, 5418/5600, 96.75%
# Processing 99301 roof tile inside 3x3 309R.png, 5419/5600, 96.77%
# Processing 99301 roof tile inside 3x3 310L.png, 5420/5600, 96.79%
# Processing 99301 roof tile inside 3x3 310R.png, 5421/5600, 96.8%
# Processing 99301 roof tile inside 3x3 311L.png, 5422/5600, 96.82%
# Processing 99301 roof tile inside 3x3 311R.png, 5423/5600, 96.84%
# Processing 99301 roof tile inside 3x3 312L.png, 5424/5600, 96.86%
# Processing 99301 roof tile inside 3x3 312R.png, 5425/5600, 96.88%
# Processing 99301 roof tile inside 3x3 313L.png, 5426/5600, 96.89%
# Processing 99301 roof tile inside 3x3 313R.png, 5427/5600, 96.91%
# Processing 99301 roof tile inside 3x3 314L.png, 5428/5600, 96.93%
# Processing 99301 roof tile inside 3x3 314R.png, 5429/5600, 96.95%
# Processing 99301 roof tile inside 3x3 315L.png, 5430/5600, 96.96%
# Processing 99301 roof tile inside 3x3 315R.png, 5431/5600, 96.98%
# Processing 99301 roof tile inside 3x3 316L.png, 5432/5600, 97.0%
# Processing 99301 roof tile inside 3x3 316R.png, 5433/5600, 97.02%
# Processing 99301 roof tile inside 3x3 317L.png, 5434/5600, 97.04%
# Processing 99301 roof tile inside 3x3 317R.png, 5435/5600, 97.05%
# Processing 99301 roof tile inside 3x3 318L.png, 5436/5600, 97.07%
# Processing 99301 roof tile inside 3x3 318R.png, 5437/5600, 97.09%
# Processing 99301 roof tile inside 3x3 319L.png, 5438/5600, 97.11%
# Processing 99301 roof tile inside 3x3 319R.png, 5439/5600, 97.12%
# Processing 99301 roof tile inside 3x3 320L.png, 5440/5600, 97.14%
# Processing 99301 roof tile inside 3x3 320R.png, 5441/5600, 97.16%
# Processing 99301 roof tile inside 3x3 321L.png, 5442/5600, 97.18%
# Processing 99301 roof tile inside 3x3 321R.png, 5443/5600, 97.2%
# Processing 99301 roof tile inside 3x3 322L.png, 5444/5600, 97.21%
# Processing 99301 roof tile inside 3x3 322R.png, 5445/5600, 97.23%
# Processing 99301 roof tile inside 3x3 323L.png, 5446/5600, 97.25%
# Processing 99301 roof tile inside 3x3 323R.png, 5447/5600, 97.27%
# Processing 99301 roof tile inside 3x3 324L.png, 5448/5600, 97.29%
# Processing 99301 roof tile inside 3x3 324R.png, 5449/5600, 97.3%
# Processing 99301 roof tile inside 3x3 325L.png, 5450/5600, 97.32%
# Processing 99301 roof tile inside 3x3 325R.png, 5451/5600, 97.34%
# Processing 99301 roof tile inside 3x3 326L.png, 5452/5600, 97.36%
# Processing 99301 roof tile inside 3x3 326R.png, 5453/5600, 97.38%
# Processing 99301 roof tile inside 3x3 327L.png, 5454/5600, 97.39%
# Processing 99301 roof tile inside 3x3 327R.png, 5455/5600, 97.41%
# Processing 99301 roof tile inside 3x3 328L.png, 5456/5600, 97.43%
# Processing 99301 roof tile inside 3x3 328R.png, 5457/5600, 97.45%
# Processing 99301 roof tile inside 3x3 329L.png, 5458/5600, 97.46%
# Processing 99301 roof tile inside 3x3 329R.png, 5459/5600, 97.48%
# Processing 99301 roof tile inside 3x3 330L.png, 5460/5600, 97.5%
# Processing 99301 roof tile inside 3x3 330R.png, 5461/5600, 97.52%
# Processing 99301 roof tile inside 3x3 331L.png, 5462/5600, 97.54%
# Processing 99301 roof tile inside 3x3 331R.png, 5463/5600, 97.55%
# Processing 99301 roof tile inside 3x3 332L.png, 5464/5600, 97.57%
# Processing 99301 roof tile inside 3x3 332R.png, 5465/5600, 97.59%
# Processing 99301 roof tile inside 3x3 333L.png, 5466/5600, 97.61%
# Processing 99301 roof tile inside 3x3 333R.png, 5467/5600, 97.62%
# Processing 99301 roof tile inside 3x3 334L.png, 5468/5600, 97.64%
# Processing 99301 roof tile inside 3x3 334R.png, 5469/5600, 97.66%
# Processing 99301 roof tile inside 3x3 335L.png, 5470/5600, 97.68%
# Processing 99301 roof tile inside 3x3 335R.png, 5471/5600, 97.7%
# Processing 99301 roof tile inside 3x3 336L.png, 5472/5600, 97.71%
# Processing 99301 roof tile inside 3x3 336R.png, 5473/5600, 97.73%
# Processing 99301 roof tile inside 3x3 337L.png, 5474/5600, 97.75%
# Processing 99301 roof tile inside 3x3 337R.png, 5475/5600, 97.77%
# Processing 99301 roof tile inside 3x3 338L.png, 5476/5600, 97.79%
# Processing 99301 roof tile inside 3x3 338R.png, 5477/5600, 97.8%
# Processing 99301 roof tile inside 3x3 339L.png, 5478/5600, 97.82%
# Processing 99301 roof tile inside 3x3 339R.png, 5479/5600, 97.84%
# Processing 99301 roof tile inside 3x3 340L.png, 5480/5600, 97.86%
# Processing 99301 roof tile inside 3x3 340R.png, 5481/5600, 97.88%
# Processing 99301 roof tile inside 3x3 341L.png, 5482/5600, 97.89%
# Processing 99301 roof tile inside 3x3 341R.png, 5483/5600, 97.91%
# Processing 99301 roof tile inside 3x3 342L.png, 5484/5600, 97.93%
# Processing 99301 roof tile inside 3x3 342R.png, 5485/5600, 97.95%
# Processing 99301 roof tile inside 3x3 343L.png, 5486/5600, 97.96%
# Processing 99301 roof tile inside 3x3 343R.png, 5487/5600, 97.98%
# Processing 99301 roof tile inside 3x3 344L.png, 5488/5600, 98.0%
# Processing 99301 roof tile inside 3x3 344R.png, 5489/5600, 98.02%
# Processing 99301 roof tile inside 3x3 345L.png, 5490/5600, 98.04%
# Processing 99301 roof tile inside 3x3 345R.png, 5491/5600, 98.05%
# Processing 99301 roof tile inside 3x3 346L.png, 5492/5600, 98.07%
# Processing 99301 roof tile inside 3x3 346R.png, 5493/5600, 98.09%
# Processing 99301 roof tile inside 3x3 347L.png, 5494/5600, 98.11%
# Processing 99301 roof tile inside 3x3 347R.png, 5495/5600, 98.12%
# Processing 99301 roof tile inside 3x3 348L.png, 5496/5600, 98.14%
# Processing 99301 roof tile inside 3x3 348R.png, 5497/5600, 98.16%
# Processing 99301 roof tile inside 3x3 349L.png, 5498/5600, 98.18%
# Processing 99301 roof tile inside 3x3 349R.png, 5499/5600, 98.2%
# Processing 99301 roof tile inside 3x3 350L.png, 5500/5600, 98.21%
# Processing 99301 roof tile inside 3x3 350R.png, 5501/5600, 98.23%
# Processing 99301 roof tile inside 3x3 351L.png, 5502/5600, 98.25%
# Processing 99301 roof tile inside 3x3 351R.png, 5503/5600, 98.27%
# Processing 99301 roof tile inside 3x3 352L.png, 5504/5600, 98.29%
# Processing 99301 roof tile inside 3x3 352R.png, 5505/5600, 98.3%
# Processing 99301 roof tile inside 3x3 353L.png, 5506/5600, 98.32%
# Processing 99301 roof tile inside 3x3 353R.png, 5507/5600, 98.34%
# Processing 99301 roof tile inside 3x3 354L.png, 5508/5600, 98.36%
# Processing 99301 roof tile inside 3x3 354R.png, 5509/5600, 98.38%
# Processing 99301 roof tile inside 3x3 355L.png, 5510/5600, 98.39%
# Processing 99301 roof tile inside 3x3 355R.png, 5511/5600, 98.41%
# Processing 99301 roof tile inside 3x3 356L.png, 5512/5600, 98.43%
# Processing 99301 roof tile inside 3x3 356R.png, 5513/5600, 98.45%
# Processing 99301 roof tile inside 3x3 357L.png, 5514/5600, 98.46%
# Processing 99301 roof tile inside 3x3 357R.png, 5515/5600, 98.48%
# Processing 99301 roof tile inside 3x3 358L.png, 5516/5600, 98.5%
# Processing 99301 roof tile inside 3x3 358R.png, 5517/5600, 98.52%
# Processing 99301 roof tile inside 3x3 359L.png, 5518/5600, 98.54%
# Processing 99301 roof tile inside 3x3 359R.png, 5519/5600, 98.55%
# Processing 99301 roof tile inside 3x3 360L.png, 5520/5600, 98.57%
# Processing 99301 roof tile inside 3x3 360R.png, 5521/5600, 98.59%
# Processing 99301 roof tile inside 3x3 361L.png, 5522/5600, 98.61%
# Processing 99301 roof tile inside 3x3 361R.png, 5523/5600, 98.62%
# Processing 99301 roof tile inside 3x3 362L.png, 5524/5600, 98.64%
# Processing 99301 roof tile inside 3x3 362R.png, 5525/5600, 98.66%
# Processing 99301 roof tile inside 3x3 363L.png, 5526/5600, 98.68%
# Processing 99301 roof tile inside 3x3 363R.png, 5527/5600, 98.7%
# Processing 99301 roof tile inside 3x3 364L.png, 5528/5600, 98.71%
# Processing 99301 roof tile inside 3x3 364R.png, 5529/5600, 98.73%
# Processing 99301 roof tile inside 3x3 365L.png, 5530/5600, 98.75%
# Processing 99301 roof tile inside 3x3 365R.png, 5531/5600, 98.77%
# Processing 99301 roof tile inside 3x3 366L.png, 5532/5600, 98.79%
# Processing 99301 roof tile inside 3x3 366R.png, 5533/5600, 98.8%
# Processing 99301 roof tile inside 3x3 367L.png, 5534/5600, 98.82%
# Processing 99301 roof tile inside 3x3 367R.png, 5535/5600, 98.84%
# Processing 99301 roof tile inside 3x3 368L.png, 5536/5600, 98.86%
# Processing 99301 roof tile inside 3x3 368R.png, 5537/5600, 98.88%
# Processing 99301 roof tile inside 3x3 369L.png, 5538/5600, 98.89%
# Processing 99301 roof tile inside 3x3 369R.png, 5539/5600, 98.91%
# Processing 99301 roof tile inside 3x3 370L.png, 5540/5600, 98.93%
# Processing 99301 roof tile inside 3x3 370R.png, 5541/5600, 98.95%
# Processing 99301 roof tile inside 3x3 371L.png, 5542/5600, 98.96%
# Processing 99301 roof tile inside 3x3 371R.png, 5543/5600, 98.98%
# Processing 99301 roof tile inside 3x3 372L.png, 5544/5600, 99.0%
# Processing 99301 roof tile inside 3x3 372R.png, 5545/5600, 99.02%
# Processing 99301 roof tile inside 3x3 373L.png, 5546/5600, 99.04%
# Processing 99301 roof tile inside 3x3 373R.png, 5547/5600, 99.05%
# Processing 99301 roof tile inside 3x3 374L.png, 5548/5600, 99.07%
# Processing 99301 roof tile inside 3x3 374R.png, 5549/5600, 99.09%
# Processing 99301 roof tile inside 3x3 375L.png, 5550/5600, 99.11%
# Processing 99301 roof tile inside 3x3 375R.png, 5551/5600, 99.12%
# Processing 99301 roof tile inside 3x3 376L.png, 5552/5600, 99.14%
# Processing 99301 roof tile inside 3x3 376R.png, 5553/5600, 99.16%
# Processing 99301 roof tile inside 3x3 377L.png, 5554/5600, 99.18%
# Processing 99301 roof tile inside 3x3 377R.png, 5555/5600, 99.2%
# Processing 99301 roof tile inside 3x3 378L.png, 5556/5600, 99.21%
# Processing 99301 roof tile inside 3x3 378R.png, 5557/5600, 99.23%
# Processing 99301 roof tile inside 3x3 379L.png, 5558/5600, 99.25%
# Processing 99301 roof tile inside 3x3 379R.png, 5559/5600, 99.27%
# Processing 99301 roof tile inside 3x3 380L.png, 5560/5600, 99.29%
# Processing 99301 roof tile inside 3x3 380R.png, 5561/5600, 99.3%
# Processing 99301 roof tile inside 3x3 381L.png, 5562/5600, 99.32%
# Processing 99301 roof tile inside 3x3 381R.png, 5563/5600, 99.34%
# Processing 99301 roof tile inside 3x3 382L.png, 5564/5600, 99.36%
# Processing 99301 roof tile inside 3x3 382R.png, 5565/5600, 99.38%
# Processing 99301 roof tile inside 3x3 383L.png, 5566/5600, 99.39%
# Processing 99301 roof tile inside 3x3 383R.png, 5567/5600, 99.41%
# Processing 99301 roof tile inside 3x3 384L.png, 5568/5600, 99.43%
# Processing 99301 roof tile inside 3x3 384R.png, 5569/5600, 99.45%
# Processing 99301 roof tile inside 3x3 385L.png, 5570/5600, 99.46%
# Processing 99301 roof tile inside 3x3 385R.png, 5571/5600, 99.48%
# Processing 99301 roof tile inside 3x3 386L.png, 5572/5600, 99.5%
# Processing 99301 roof tile inside 3x3 386R.png, 5573/5600, 99.52%
# Processing 99301 roof tile inside 3x3 387L.png, 5574/5600, 99.54%
# Processing 99301 roof tile inside 3x3 387R.png, 5575/5600, 99.55%
# Processing 99301 roof tile inside 3x3 388L.png, 5576/5600, 99.57%
# Processing 99301 roof tile inside 3x3 388R.png, 5577/5600, 99.59%
# Processing 99301 roof tile inside 3x3 389L.png, 5578/5600, 99.61%
# Processing 99301 roof tile inside 3x3 389R.png, 5579/5600, 99.62%
# Processing 99301 roof tile inside 3x3 390L.png, 5580/5600, 99.64%
# Processing 99301 roof tile inside 3x3 390R.png, 5581/5600, 99.66%
# Processing 99301 roof tile inside 3x3 391L.png, 5582/5600, 99.68%
# Processing 99301 roof tile inside 3x3 391R.png, 5583/5600, 99.7%
# Processing 99301 roof tile inside 3x3 392L.png, 5584/5600, 99.71%
# Processing 99301 roof tile inside 3x3 392R.png, 5585/5600, 99.73%
# Processing 99301 roof tile inside 3x3 393L.png, 5586/5600, 99.75%
# Processing 99301 roof tile inside 3x3 393R.png, 5587/5600, 99.77%
# Processing 99301 roof tile inside 3x3 394L.png, 5588/5600, 99.79%
# Processing 99301 roof tile inside 3x3 394R.png, 5589/5600, 99.8%
# Processing 99301 roof tile inside 3x3 395L.png, 5590/5600, 99.82%
# Processing 99301 roof tile inside 3x3 395R.png, 5591/5600, 99.84%
# Processing 99301 roof tile inside 3x3 396L.png, 5592/5600, 99.86%
# Processing 99301 roof tile inside 3x3 396R.png, 5593/5600, 99.88%
# Processing 99301 roof tile inside 3x3 397L.png, 5594/5600, 99.89%
# Processing 99301 roof tile inside 3x3 397R.png, 5595/5600, 99.91%
# Processing 99301 roof tile inside 3x3 398L.png, 5596/5600, 99.93%
# Processing 99301 roof tile inside 3x3 398R.png, 5597/5600, 99.95%
# Processing 99301 roof tile inside 3x3 399L.png, 5598/5600, 99.96%
# Processing 99301 roof tile inside 3x3 399R.png, 5599/5600, 99.98%

# %%
df_schema = {
    'code': pl.Utf8,
    'shape': pl.Int64,
    'area': pl.Float64,
    'score': pl.Int64,
    'percent': pl.Float64,
    'circles': pl.Int64,
    'num_lines': pl.Int64,
    'corners': pl.Int64
}

# %%
df = pl.DataFrame(results, df_schema)
df
# Out:
# shape: (5_600, 8)
# ┌───────┬───────┬─────────┬───────┬─────────┬─────────┬───────────┬─────────┐
# │ code  ┆ shape ┆ area    ┆ score ┆ percent ┆ circles ┆ num_lines ┆ corners │
# │ ---   ┆ ---   ┆ ---     ┆ ---   ┆ ---     ┆ ---     ┆ ---       ┆ ---     │
# │ str   ┆ i64   ┆ f64     ┆ i64   ┆ f64     ┆ i64     ┆ i64       ┆ i64     │
# ╞═══════╪═══════╪═════════╪═══════╪═════════╪═════════╪═══════════╪═════════╡
# │ 2780  ┆ 18    ┆ 7415.0  ┆ 77    ┆ 19.25   ┆ 2       ┆ 0         ┆ 39      │
# │ 2780  ┆ 12    ┆ 8439.5  ┆ 68    ┆ 17.0    ┆ 0       ┆ 0         ┆ 34      │
# │ 2780  ┆ 14    ┆ 7019.5  ┆ 66    ┆ 16.5    ┆ 3       ┆ 0         ┆ 39      │
# │ 2780  ┆ 14    ┆ 8599.5  ┆ 68    ┆ 17.0    ┆ 0       ┆ 0         ┆ 37      │
# │ …     ┆ …     ┆ …       ┆ …     ┆ …       ┆ …       ┆ …         ┆ …       │
# │ 99301 ┆ 10    ┆ 39365.5 ┆ 123   ┆ 30.75   ┆ 0       ┆ 1         ┆ 43      │
# │ 99301 ┆ 6     ┆ 65092.0 ┆ 71    ┆ 17.75   ┆ 0       ┆ 0         ┆ 62      │
# │ 99301 ┆ 6     ┆ 73821.0 ┆ 186   ┆ 46.5    ┆ 1       ┆ 3         ┆ 77      │
# │ 99301 ┆ 16    ┆ 47921.5 ┆ 81    ┆ 20.25   ┆ 0       ┆ 0         ┆ 53      │
# └───────┴───────┴─────────┴───────┴─────────┴─────────┴───────────┴─────────┘

# %%
df.write_csv('Synthetic_Data.csv')
